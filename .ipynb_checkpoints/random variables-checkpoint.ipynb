# %% [markdown]
# # Lab | Random variable distributions

# %% [markdown]
# ### 1. Use the numerical variables from our dataset this week.

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
numerical=pd.read_csv('numerical.csv')
numerical
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %% [markdown]
# ### 2. Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.

# %%
for col in numerical.columns:
    sns.displot(numerical[col],kde=True)
    plt.show()

# %% [markdown]
# From the above plots, we cant say for sure if the variables follow normal distribution. \
# Also some variables need to be stretched to check if they follow normal distribution.

# %% [markdown]
# ### 3. Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.

# %% [markdown]
# ### Log Transformation

# %%
num_transformed=np.where(np.isfinite(np.log10(numerical)),np.log10(numerical),0)
# Out:
# C:\Users\jaine\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:351: RuntimeWarning: divide by zero encountered in log10
#   result = func(self.values, **kwargs)

# %%
#the result is an array so converting it to a datafranme for better readability and plotting

num_transformed=pd.DataFrame(num_transformed,columns=numerical.columns)
num_transformed
# Out:
#       customer_lifetime_value    income  monthly_premium_auto  \
# 0                    3.441462  4.750308              1.838849
# 1                    3.843827  0.000000              1.973128
# 2                    4.110166  4.688126              2.033424
# 3                    3.883426  0.000000              2.025306
# 4                    3.449277  4.641831              1.863323
# ...                       ...       ...                   ...
# 9129                 4.369327  4.856976              1.863323
# 9130                 3.490873  4.334534              1.897627
# 9131                 3.911897  0.000000              1.929419
# 9132                 3.876474  4.341256              1.982271
# 9133                 3.416946  0.000000              1.886491
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                    1.505150                       0.698970
# 1                    1.113943                       1.623249
# ...

# %%
for col in num_transformed.columns:
    sns.displot(num_transformed[col],kde=True)
    plt.show()

# %% [markdown]
# ### Square Root Transformation
# https://www.statology.org/transform-data-in-python/

# %%
num_sqrt=np.sqrt(numerical)
num_sqrt
# Out:
#       customer_lifetime_value      income  monthly_premium_auto  \
# 0                   52.569186  237.221416              8.306624
# 1                   83.543617    0.000000              9.695360
# 2                  113.522824  220.832516             10.392305
# 3                   87.440619    0.000000             10.295630
# 4                   53.044251  209.370485              8.544004
# ...                       ...         ...                   ...
# 9129               152.990156  268.218195              8.544004
# 9130                55.646305  146.982992              8.888194
# 9131                90.354250    0.000000              9.219544
# 9132                86.743544  148.124947              9.797959
# 9133                51.106133    0.000000              8.774964
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                    5.656854                       2.236068
# 1                    3.605551                       6.480741
# ...

# %%
for col in num_sqrt.columns:
    sns.displot(num_sqrt[col],kde=True)
    plt.show()

# %% [markdown]
# ### Cubic Root Transformation

# %%
num_cbrt=np.cbrt(numerical)
num_cbrt
# Out:
#       customer_lifetime_value     income  monthly_premium_auto  \
# 0                   14.033118  38.320920              4.101566
# 1                   19.110652   0.000000              4.546836
# 2                   23.445282  36.534964              4.762203
# 3                   19.700420   0.000000              4.732623
# 4                   14.117535  35.259567              4.179339
# ...                       ...        ...                   ...
# 9129                28.605025  41.590310              4.179339
# 9130                14.575525  27.851252              4.290840
# 9131                20.135653   0.000000              4.396830
# 9132                19.595579  27.995322              4.578857
# 9133                13.771524   0.000000              4.254321
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                    3.174802                       1.709976
# 1                    2.351335                       3.476027
# ...

# %%
for col in num_cbrt.columns:
    sns.displot(num_cbrt[col],kde=True)
    plt.show()
